# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.drop(['Maxpulse'],axis=1,inplace=True)
data
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.4
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
num = data.loc[0,'Duration']
print(num)
num1 = data.loc[0]
print(num1)
# Out:
# 60
# Duration     60.0
# Pulse       110.0
# Calories    409.1
# Name: 0, dtype: float64

# %%
num = data.iloc[0,1]
print(num)
num1 = data.iloc[0:2,0:3]
print(num1)
# Out:
# 110
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0

# %%
groupA = data.groupby("Duration")

for i,j in groupA:
    print(i)
    print(j)
# Out:
# 15
#      Duration  Pulse  Maxpulse  Calories
# 93         15     80       100      50.5
# 112        15    124       139     124.2
# 20
#      Duration  Pulse  Maxpulse  Calories
# 58         20    153       172     226.4
# 64         20    110       130     131.4
# 68         20    106       136     110.4
# 89         20     83       107      50.3
# 94         20    150       171     127.4
# 95         20    151       168     229.4
# 100        20     95       112      77.7
# 135        20    136       156     189.0
# 139        20    141       162     222.4
# 25
#     Duration  Pulse  Maxpulse  Calories
# 97        25    152       168     244.2
# 30
#      Duration  Pulse  Maxpulse  Calories
# 8          30    109       133     195.1
# 54         30    136       175     238.0
# 80         30    159       182     319.2
# 82         30    103       139     151.1
# 85         30    151       170     300.1
# 92         30     90       107     105.3
# ...

# %%
groupA.get_group(60)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# ..        ...    ...       ...       ...
# 157        60    100       120     270.4
# 158        60    114       150     382.8
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
#
# [79 rows x 4 columns]

# %%
groupA.min()
# Out:
#           Pulse  Maxpulse  Calories
# Duration
# 15           80       100      50.5
# 20           83       107      50.3
# 25          152       168     244.2
# 30           80       107      86.2
# 45           90       103     100.7
# 60           92       101     215.2
# 75          120       150     320.4
# 80          123       146     643.1
# 90           90       100     466.4
# 120         100       130     500.0
# 150          97       127     816.0
# 160         109       135     853.0
# 180          90       120     600.1
# 210         108       160    1376.0
# 270         100       131    1729.0
# 300         108       143    1500.2

# %%
groupA.mean()
# Out:
#                Pulse    Maxpulse     Calories
# Duration
# 15        102.000000  119.500000    87.350000
# 20        125.000000  146.000000   151.600000
# 25        152.000000  168.000000   244.200000
# 30        109.812500  137.000000   192.131250
# 45        107.485714  133.228571   273.236364
# 60        106.126582  132.860759   339.694737
# 75        122.500000  150.000000   325.400000
# 80        123.000000  146.000000   643.100000
# 90         93.750000  116.375000   541.800000
# 120       100.000000  139.000000   666.833333
# 150       101.500000  130.250000   939.400000
# 160       109.500000  136.000000   943.700000
# 180        93.666667  125.666667   733.600000
# 210       122.500000  172.000000  1618.200000
# 270       100.000000  131.000000  1729.000000
# 300       108.000000  143.000000  1500.200000
